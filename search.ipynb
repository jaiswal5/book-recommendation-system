# %%
# !wc -l C:\Users\Anand\Downloads\goodreads_books.json.gz
# Out:
# 'wc' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !find /c /v "" C:\Users\Anand\Downloads\goodreads_books.json.gz
# Out:
# ---------- C:\USERS\ANAND\DOWNLOADS\GOODREADS_BOOKS.JSON.GZ: 14471322

# %%
# !ls -lh | grep C:\Users\Anand\Downloads\goodreads_books.json.gz
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import gzip

with gzip.open(r'C:\Users\Anand\Downloads\goodreads_books.json.gz') as f:
    line = f.readline()

# %%
line
# Out:
# b'{"isbn": "0312853122", "text_reviews_count": "1", "series": [], "country_code": "US", "language_code": "", "popular_shelves": [{"count": "3", "name": "to-read"}, {"count": "1", "name": "p"}, {"count": "1", "name": "collection"}, {"count": "1", "name": "w-c-fields"}, {"count": "1", "name": "biography"}], "asin": "", "is_ebook": "false", "average_rating": "4.00", "kindle_asin": "", "similar_books": [], "description": "", "format": "Paperback", "link": "https://www.goodreads.com/book/show/5333265-w-c-fields", "authors": [{"author_id": "604031", "role": ""}], "publisher": "St. Martin\'s Press", "num_pages": "256", "publication_day": "1", "isbn13": "9780312853129", "publication_month": "9", "edition_information": "", "publication_year": "1984", "url": "https://www.goodreads.com/book/show/5333265-w-c-fields", "image_url": "https://images.gr-assets.com/books/1310220028m/5333265.jpg", "book_id": "5333265", "ratings_count": "3", "work_id": "5400751", "title": "W.C. Fields: A Life on Film", 
# ...

# %%
import json
json.loads(line)
# Out:
# {'isbn': '0312853122',
#  'text_reviews_count': '1',
#  'series': [],
#  'country_code': 'US',
#  'language_code': '',
#  'popular_shelves': [{'count': '3', 'name': 'to-read'},
#   {'count': '1', 'name': 'p'},
#   {'count': '1', 'name': 'collection'},
#   {'count': '1', 'name': 'w-c-fields'},
#   {'count': '1', 'name': 'biography'}],
#  'asin': '',
#  'is_ebook': 'false',
#  'average_rating': '4.00',
#  'kindle_asin': '',
#  'similar_books': [],
#  'description': '',
#  'format': 'Paperback',
#  'link': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'authors': [{'author_id': '604031', 'role': ''}],
#  'publisher': "St. Martin's Press",
#  'num_pages': '256',
#  'publication_day': '1',
#  'isbn13': '9780312853129',
#  'publication_month': '9',
#  'edition_information': '',
#  'publication_year': '1984',
#  'url': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'image_url': 'https://images.gr-assets.com/books/1310220028m/5333265.jpg',
# ...

# %%
def parse_fields(line):
    data = json.loads(line)
    return{
        "book_id": data["book_id"],
        "title": data["title_without_series"],
        "ratings": data["ratings_count"],
        "url": data["url"],
        "cover_image": data["image_url"]
    }

# %%
books_titles = []
with gzip.open(r'C:\Users\Anand\Downloads\goodreads_books.json.gz') as f:
    while True:
        line = f.readline()
        if not line:
            break
        fields = parse_fields(line)
        
        try:
            ratings = int(fields["ratings"])
        except ValueError:
            continue
        if ratings > 15:
            books_titles.append(fields)

# %%
books_titles
# Out:
# [{'book_id': '7327624',
#   'title': 'The Unschooled Wizard (Sun Wolf and Starhawk, #1-2)',
#   'ratings': '140',
#   'url': 'https://www.goodreads.com/book/show/7327624-the-unschooled-wizard',
#   'cover_image': 'https://images.gr-assets.com/books/1304100136m/7327624.jpg'},
#  {'book_id': '6066819',
#   'title': 'Best Friends Forever',
#   'ratings': '51184',
#   'url': 'https://www.goodreads.com/book/show/6066819-best-friends-forever',
#   'cover_image': 'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'},
#  {'book_id': '287141',
#   'title': 'The Aeneid for Boys and Girls',
#   'ratings': '46',
#   'url': 'https://www.goodreads.com/book/show/287141.The_Aeneid_for_Boys_and_Girls',
#   'cover_image': 'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'},
#  {'book_id': '6066812',
#   'title': "All's Fairy in Love and War (Avalon: Web of Magic, #8)",
#   'ratings': '98',
# ...

# %%
import pandas as pd
titles = pd.DataFrame.from_dict(books_titles)

# %%
titles
# Out:
#           book_id                                              title ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...     140
# 1         6066819                               Best Friends Forever   51184
# 2          287141                      The Aeneid for Boys and Girls      46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...      98
# 4          287149                               The Devil's Notebook     986
# ...           ...                                                ...     ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)     327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts      18
# 1308954   2685097                   The Spaniard's Blackmailed Bride     112
# 1308955   2342551           The Children's Classic Poetry Collection      36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)      70
#
# ...

# %%
titles["ratings"] = pd.to_numeric(titles["ratings"])

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
# ...

# %%
titles["mod_title"] = titles["title"].str.replace("[^a-zA-Z0-9 ]", "",regex=True)

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
# ...

# %%
titles["mod_title"] = titles["mod_title"].str.lower()

# %%
titles["mod_title"] = titles["mod_title"].str.replace("\s+"," ", regex=True)

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
# ...

# %%
titles = titles[titles["mod_title"].str.len() > 0]

# %%
titles.to_json("books_titles.json")

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()

tfidf = vectorizer.fit_transform(titles["mod_title"])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re

def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)
def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

def search(query, vectorizer):
    processed = re.sub("[^a-zA-Z0-9 ]","", query.lower())
    query_vec = vectorizer.transform([processed])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity,-10)[-10:]
    results = titles.iloc[indices]
    results = results.sort_values("ratings", ascending=False)
    return results.head(10).style.format({'url': make_clickable, 'cover_image': show_image})

# %%
similarity
# Out:
# array([0.01370211, 0.        , 0.0207964 , ..., 0.01874445, 0.02078223,
#        0.        ])

# %%
search("The Subtle Art of Not Giving a F*ck", vectorizer)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ebbe4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebbe4_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_ebbe4_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_ebbe4_level0_col2" class="col_heading level0 col2" >ratings</th>
#       <th id="T_ebbe4_level0_col3" class="col_heading level0 col3" >url</th>
#       <th id="T_ebbe4_level0_col4" class="col_heading level0 col4" >cover_image</th>
#       <th id="T_ebbe4_level0_col5" class="col_heading level0 col5" >mod_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebbe4_level0_row0" class="row_heading level0 row0" >113372</th>
#       <td id="T_ebbe4_row0_col0" class="data row0 col0" >28257707</td>
#       <td id="T_ebbe4_row0_col1" class="data row0 col1" >The Subtle Art of Not Giving a F*ck: A Counterintuitive Approach to Living a Good Life</td>
# ...
